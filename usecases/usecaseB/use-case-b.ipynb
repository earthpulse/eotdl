# %% [markdown]
# <img src="..."
# style="width: 20%; display: block; margin-left: 0px; margin-right: auto;">

# %%
# %load_ext autoreload
# %autoreload 2

# %load_ext dotenv
# %dotenv

# %% [markdown]
# <h1 style="text-align:center;font-size:02.2vw;">SEN12-FLOOD dataset</h1>

# %% [markdown]
# In this use case we are going to develop a Data Fusion dataset for flood detection consisting of S1-S2-DEM triplets with manually labelled water masks for flooding detection. This dataset will be built upon the already existing `SEN12-FLOOD` dataset, which will be improved with DEM data and additional samples for recent floods and new geographical areas (mainly Europe and Asia).

# %% [markdown]
# # Dataset

# %% [markdown]
# `SEN12-FLOOD` is a set of multimodal (SAR + multispectral) satellite image time-series for flood
# classification.
# The observed areas correspond to 337 locations (cities and their surroundings ) in West and SouthEast Africa, Middle-East, and Australia where a flood event occurred during the considered period.
# The period of acquisition goes from December 2018 to May 2019.
#
# For each location, the following data are provided:
# - Time series of Sentinel-2 multispectral images. These images are composed of 12 bands,
# at 10m ground-sampling distance and are provided with Level 2A atmospheric correction.
# - Time series of Sentinel-1 Synthetic Aperture Radar (SAR) images. The images are provided
# with radiometric calibration and range doppler terrain correction based on the SRTM digital
# elevation model. For one acquisition, two raster images are available corresponding to the
# polarimetry channels VV and VH.
# - Time series of binary labels for each image / date: flood or no flood.
# The original dataset was split into 262 sequences for the train and 68 sequences for the test.
#
# [Source](https://radiantearth.blob.core.windows.net/mlhub/sen12floods/documentation.pdf)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import geopandas as gpd
import warnings

from matplotlib import pyplot as plt
from shapely.geometry import box

from os.path import join
from os import getenv
from shapely.geometry import Polygon

# %% [markdown]
# # Set up Radiant MLHub Python Client

# %% [markdown]
# The [Radiant MLHub Python Client](https://radiant-mlhub.readthedocs.io/en/latest/) can be used to search datasets on Radiant MLHub and easily download them to your local environment. In this use case, we will use it to download the `sen12floods` dataset.

# %% [markdown]
# ### Python Client Quick-Start guide
# 1. Get a Radiant MLHub API Key from your [Settings](https://mlhub.earth/profile) page.
# 2. Install and configure the MLHub Python Client from the command line:
#
# ```
# $ mlhub configure
# API Key: Enter your API key here...
# Wrote profile to /Users/youruser/.mlhub/profiles
# ```

# %% [markdown]
# # Download the dataset

# %% [markdown]
# As said, the dataset can be easily downlaoded directly from Radiant MLHub with few code lines.

# %%
from radiant_mlhub import Dataset

ds = Dataset.fetch('sen12floods')

# By default, the dataset will be downloaded as 'sen12floods.tar.gz' and extracted in the 'sen12floods' directory 
# If desired, you can pass a custom output directory as output_dir to the ds.download function
# %time ds.download()

# Remove the .tar file
# !rm sen12floods.tar.gz

# %% [markdown]
# # Explore the dataset

# %% [markdown]
# In order to enrich the dataset with new sequences and images, for both existing and new locations and from 2019 to 2022, it is useful to know the number of images per location and per Sentinel mission. So, we have to explore the dataset a bit.

# %% [markdown]
# ### Get the number of images by existing location

# %% [markdown]
# Let's dive into the dataset. First of all, we need to know the amount of images already available for each existing location. We will use this information later.
#
# To do so we are going to use [PySTAC](https://pystac.readthedocs.io/en/stable/), a library for working with [SpatioTemporal Asset Catalogs (STAC)](https://stacspec.org/en) in Python 3, and the eotdl library.

# %%
from eotdl.tools import stac_items_to_gdf, get_images_by_location

# %%
from pystac import Catalog

ROOT = getenv('ROOT_SEN12FLOODS')
# ROOT = 'sen12floods'   # Set here the local path to the sen12floods directory from the downloaded dataset

# %%
root_catalog = Catalog.from_file(join(ROOT, 'catalog.json'))

# %% [markdown]
# Sentinel-1

# %%
s1_source_pystac = root_catalog.get_child('sen12floods_s1_source')   # Access the sen12floods_s1_source pystac.Collection
s1_items = s1_source_pystac.get_all_items()   # Get a pystac.ItemCollection from the Collection
s1_gdf = stac_items_to_gdf(s1_items)   # Convert the ItemCollection into a GeoDataFrame
s1_gdf.head()
# Out:
#                                             geometry              datetime  \
# 0  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...  2018-12-23T00:00:00Z
# 1  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...  2019-01-04T00:00:00Z
# 2  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...  2019-01-16T00:00:00Z
# 3  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...  2019-01-28T00:00:00Z
# 4  POLYGON ((18.62733 -33.84958, 18.62606 -33.895...  2018-12-16T00:00:00Z
#
#   sar:frequency_band sar:instrument_mode sar:polarizations sar:product_type  \
# 0                  C                  EW          [VV, VH]              GRD
# 1                  C                  EW          [VV, VH]              GRD
# 2                  C                  EW          [VV, VH]              GRD
# 3                  C                  EW          [VV, VH]              GRD
# 4                  C                  EW          [VV, VH]              GRD
#
#   constellation instruments     mission  gsd     platform  proj:epsg  \
# 0    sentinel-1     [c-sar]  sentinel-1   10  SENTINEL-1A       4326
# 1    sentinel-1     [c-sar]  sentinel-1   10  SENTINEL-1A       4326
# 2    sentinel-1     [c-sar]  sentinel-1   10  SENTINEL-1A       4326
# 3    sentinel-1     [c-sar]  sentinel-1   10  SENTINEL-1A       4326
# 4    sentinel-1     [c-sar]  sentinel-1   10  SENTINEL-1A       4326
#
#                                       proj:transform  proj:shape  \
# 0  [8.983152841195215e-05, 0.0, -13.2783532841656...  [518, 521]
# 1  [8.983152841195215e-05, 0.0, -13.2783689470001...  [519, 521]
# 2  [8.983152841195215e-05, 0.0, -13.2783084495239...  [519, 520]
# 3  [8.983152841195215e-05, 0.0, -13.2783190616426...  [519, 521]
# 4  [8.983152841195215e-05, 0.0, 18.62602873044632...  [526, 630]
#
#                                       id scene_id     type  \
# 0  sen12floods_s1_source_0001_2018_12_23     0001  Feature
# 1  sen12floods_s1_source_0001_2019_01_04     0001  Feature
# 2  sen12floods_s1_source_0001_2019_01_16     0001  Feature
# 3  sen12floods_s1_source_0001_2019_01_28     0001  Feature
# 4  sen12floods_s1_source_0004_2018_12_16     0004  Feature
#
#                                      stac_extensions
# 0  [https://stac-extensions.github.io/sar/v1.0.0/...
# 1  [https://stac-extensions.github.io/sar/v1.0.0/...
# 2  [https://stac-extensions.github.io/sar/v1.0.0/...
# 3  [https://stac-extensions.github.io/sar/v1.0.0/...
# 4  [https://stac-extensions.github.io/sar/v1.0.0/...

# %%
s1_images = get_images_by_location(s1_gdf)   # Count and get the date of all the images available for a unique location
s1_images.head()
# Out:
#   scene_id  dates_count                                         dates_list
# 0        0           13  [2019-02-06T00:00:00Z, 2019-02-18T00:00:00Z, 2...
# 1     0001            4  [2018-12-23T00:00:00Z, 2019-01-04T00:00:00Z, 2...
# 2     0004            5  [2018-12-16T00:00:00Z, 2018-12-21T00:00:00Z, 2...
# 3     0005            5  [2018-12-16T00:00:00Z, 2018-12-21T00:00:00Z, 2...
# 4     0006            5  [2018-12-16T00:00:00Z, 2018-12-21T00:00:00Z, 2...

# %% [markdown]
# Sentinel-2

# %%
s2_source_pystac = root_catalog.get_child('sen12floods_s2_source')
s2_items = s2_source_pystac.get_all_items()
s2_gdf = stac_items_to_gdf(s2_items)
s2_gdf.head()
# Out:
#                                             geometry constellation  \
# 0  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...    sentinel-2
# 1  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...    sentinel-2
# 2  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...    sentinel-2
# 3  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...    sentinel-2
# 4  POLYGON ((-13.27805 8.49353, -13.27825 8.44724...    sentinel-2
#
#                datetime                                           eo:bands  \
# 0  2018-12-18T00:00:00Z  [{'name': 'B01', 'common_name': 'coastal', 'de...
# 1  2018-12-23T00:00:00Z  [{'name': 'B01', 'common_name': 'coastal', 'de...
# 2  2019-01-02T00:00:00Z  [{'name': 'B01', 'common_name': 'coastal', 'de...
# 3  2019-01-12T00:00:00Z  [{'name': 'B01', 'common_name': 'coastal', 'de...
# 4  2019-01-17T00:00:00Z  [{'name': 'B01', 'common_name': 'coastal', 'de...
#
#    gsd instruments     platform     mission  proj:epsg  \
# 0   10       [msi]  Sentinel-2B  sentinel-2      32628
# 1   10       [msi]  Sentinel-2A  sentinel-2      32628
# 2   10       [msi]  Sentinel-2A  sentinel-2      32628
# 3   10       [msi]  Sentinel-2A  sentinel-2      32628
# 4   10       [msi]  Sentinel-2B  sentinel-2      32628
#
#                                       proj:transform proj:shape  \
# 0  [60.0, 0.0, 689520.0, 0.0, -60.0, 939300.0, 0....   [85, 85]
# 1  [60.0, 0.0, 689520.0, 0.0, -60.0, 939300.0, 0....   [85, 85]
# 2  [60.0, 0.0, 689520.0, 0.0, -60.0, 939300.0, 0....   [85, 85]
# 3  [60.0, 0.0, 689520.0, 0.0, -60.0, 939300.0, 0....   [85, 85]
# 4  [60.0, 0.0, 689520.0, 0.0, -60.0, 939300.0, 0....   [85, 85]
#
#                                       id scene_id     type  \
# 0  sen12floods_s2_source_0001_2018_12_18     0001  Feature
# 1  sen12floods_s2_source_0001_2018_12_23     0001  Feature
# 2  sen12floods_s2_source_0001_2019_01_02     0001  Feature
# 3  sen12floods_s2_source_0001_2019_01_12     0001  Feature
# 4  sen12floods_s2_source_0001_2019_01_17     0001  Feature
#
#                                      stac_extensions
# 0  [https://stac-extensions.github.io/eo/v1.1.0/s...
# 1  [https://stac-extensions.github.io/eo/v1.1.0/s...
# 2  [https://stac-extensions.github.io/eo/v1.1.0/s...
# 3  [https://stac-extensions.github.io/eo/v1.1.0/s...
# 4  [https://stac-extensions.github.io/eo/v1.1.0/s...

# %%
s2_images = get_images_by_location(s2_gdf)
s2_images.head()
# Out:
#   scene_id  dates_count                                         dates_list
# 0        0            9  [2019-01-26T00:00:00Z, 2019-01-31T00:00:00Z, 2...
# 1     0001            9  [2018-12-18T00:00:00Z, 2018-12-23T00:00:00Z, 2...
# 2     0004            9  [2018-12-15T00:00:00Z, 2018-12-17T00:00:00Z, 2...
# 3     0005            9  [2018-12-15T00:00:00Z, 2018-12-17T00:00:00Z, 2...
# 4     0006            9  [2018-12-15T00:00:00Z, 2018-12-17T00:00:00Z, 2...

# %%
print(f'Number of unique locations in Sentinel1 (SAR) data : {s1_gdf.scene_id.nunique()}')
print(f'Number of images in Sentinel1 (SAR) : {len(s1_gdf.index)}')
print(f'Average images in Sentinel1 (SAR) by unique location: {round(len(s1_gdf.index)/s1_gdf.scene_id.nunique(), 2)}')
print('')
print(f'Number of unique locations in Sentinel2 (optical) data : {s2_gdf.scene_id.nunique()}')
print(f'Number of images in Sentinel2 (optical) : {len(s2_gdf.index)}')
print(f'Average images in Sentinel2 (optical) by unique location: {round(len(s2_gdf.index)/s2_gdf.scene_id.nunique(), 2)}')
# Out:
# Number of unique locations in Sentinel1 (SAR) data : 335
# Number of images in Sentinel1 (SAR) : 3331
# Average images in Sentinel1 (SAR) by unique location: 9.94
#
# Number of unique locations in Sentinel2 (optical) data : 335
# Number of images in Sentinel2 (optical) : 2236
# Average images in Sentinel2 (optical) by unique location: 6.67

# %% [markdown]
# # Get new locations

# %% [markdown]
# If we wan to to improve the existing dataset with additional samples for new locations, we need firstly to know where and when flooding events have occured in order to know which imagery data we need to download. To do so, we are going to use the [Global Archive of large floods](https://floodobservatory.colorado.edu/Archives/index.html) from the [Darmouth flood overvatory](https://floodobservatory.colorado.edu/), which has data from 1985 to 2021.

# %% [markdown]
# ## Clean the archive

# %%
archive_url = 'https://floodobservatory.colorado.edu/temp/FloodArchive.txt'

flood_archive_df = pd.read_csv(archive_url, sep='\t', encoding = "ISO-8859-1")
flood_archive_df.head()
# Out:
#    ID GlideNumber      Country OtherCountry       long       lat       Area  \
# 0   1           0      Algeria            0    5.23026  35.81420   92615.67
# 1   2           0       Brazil            0  -45.34890 -18.71110  678498.82
# 2   3           0  Phillipines            0  122.97400  10.02070   12846.03
# 3   4           0    Indonesia            0  124.60600   1.01489   16542.12
# 4   5           0   Mozambique            0   32.34910 -25.86930   20082.21
#
#       Began     Ended Validation  Dead  Displaced        MainCause  Severity
# 0  19850101  19850105       News    26       3000       Heavy rain       1.0
# 1  19850115  19850202       News   229      80000       Heavy rain       2.0
# 2  19850120  19850121       News    43        444  Torrential rain       1.0
# 3  19850204  19850218       News    21        300  Torrential rain       1.0
# 4  19850209  19850211       News    19          0       Heavy rain       2.0

# %% [markdown]
# As said, the dataset contains data from 1985 to 2021, so let's clean it to the desired time lapse, which is 2018-2022. Firstly, but, we need to transform the `Began` and `Ended` columns, as them format is not the desired.

# %%
from datetime import datetime

flood_archive_df['Began'] = flood_archive_df['Began'].apply(lambda x: datetime.strptime(str(x), '%Y%m%d'))
flood_archive_df['Ended'] = flood_archive_df['Ended'].apply(lambda x: datetime.strptime(str(x), '%Y%m%d'))

flood_archive_df = flood_archive_df[(flood_archive_df['Began'] >= '2018-01-01') & (flood_archive_df['Began'] <= '2021-12-31')]

# %% [markdown]
# Now we have what we want.

# %%
flood_archive_df.head()
# Out:
#         ID          GlideNumber                       Country    OtherCountry  \
# 4553  4556                  NaN  Democratic Republic of Congo             NaN
# 4554  4557                  NaN                       Ireland  United Kingdom
# 4555  4558                  NaN                      Malaysia             NaN
# 4556  4559  TC-2018-0000001-MDG                    Madagascar             NaN
# 4557  4560                  NaN                           USA             NaN
#
#            long       lat       Area      Began      Ended Validation  Dead  \
# 4553   15.11620  -4.35476    5597.13 2018-01-03 2018-01-05       News    37
# 4554   -1.18977  49.23120  103273.70 2018-01-02 2018-01-04       News     2
# 4555  102.33700   3.65883  117492.07 2018-01-01 2018-01-05       News     2
# 4556   47.53020 -20.23920  166873.67 2018-01-05 2018-01-08       News     6
# 4557 -118.40000  33.86890   12771.17 2018-01-09 2018-01-11       News    15
#
#       Displaced            MainCause  Severity
# 4553          0      Torrential Rain       1.5
# 4554          0  Storm Surge Eleanor       1.5
# 4555      12000       Monsoonal Rain       1.5
# 4556      15000   Tropical Storm Ava       1.5
# 4557       1200      Torrential Rain       2.0

# %% [markdown]
# ## Create the spatial dataset

# %% [markdown]
# It's time to convert the DataFrame into a GeoDataFrame with coordinates.

# %%
_flood_archive_gdf = gpd.GeoDataFrame(
    flood_archive_df, geometry=gpd.points_from_xy(flood_archive_df.long, flood_archive_df.lat))

_flood_archive_gdf = _flood_archive_gdf.set_crs(4326)

# %% [markdown]
# Now, we must filter the locations by continent, as we only want Europe and Asia for new locations. Eventhough, we are going to maintain events for Africa and Australia, as we also want to know if there have been new flooding events in the locations already existing in the dataset.

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

aoi = world[(world.continent.isin(['Europe', 'Asia', 'Africa'])) | (world.name == 'Australia')]

flood_archive_gdf = gpd.clip(_flood_archive_gdf, aoi)

print(f'The dataset contains {len(flood_archive_gdf.index)} flooding events along Europe, Asia, Africa and Australia.')
# Out:
# The dataset contains 408 flooding events along Europe, Asia, Africa and Australia.

# %% [markdown]
# ## Calculate the bounding box for new locations

# %% [markdown]
# Now that we have the flooding events archive as a GeoDataFrame, we need to generate the bounding box of each location in order to get the corresponding imagery data. To accomplish that, and knowing that the size of the existing bounding boxes vary between locations, we are going to do the following:
# 1. Calculate the mean size of the bounding boxes.
# 2. Generate the bounding box of every new location with the obtained mean size.
#
# Firstly, in order to calculate the mean size of the bounding boxes we are going to calculate the average difference between maximum and minimum coordinates, so we will need the bounding box of every existing location.
#
# Let's get it.

# %%
# As the bounding boxes between Sentinel-1 and Sentinel-2 are equal,
# we just need them from one dataset and not from both
s1_gdf_unique = s1_gdf.drop_duplicates(subset='scene_id')

# Calculate a temporary column called bounding_box to get the bounding box as a list,
# and not as a shapely.geometry object. This way is easier to digest.
s1_gdf_unique['bounding_box'] = s1_gdf_unique.apply (lambda row: row.geometry.bounds, axis=1)

bbox_by_existing_location = s1_gdf_unique.set_index('scene_id').to_dict()['bounding_box']

del s1_gdf_unique
# Out:
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/geopandas/geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
print(bbox_by_existing_location)
# Out:
# {'0001': (-13.278254, 8.447033, -13.231551, 8.493532), '0004': (18.626057, -33.896767, 18.682633, -33.849575), '0005': (18.681385, -33.897797, 18.737935, -33.850628), '0006': (18.680135, -33.943938, 18.736717, -33.896767), '0007': (36.657265, -1.242004, 36.703289, -1.19568), '0009': (36.749236, -1.242082, 36.795262, -1.195757), '0010': (36.795224, -1.242121, 36.84125, -1.195795), '0011': (36.841213, -1.242158, 36.88724, -1.195832), '0012': (36.657223, -1.288288, 36.70325, -1.241963), '0013': (36.703209, -1.288329, 36.749236, -1.242004), '0014': (36.749196, -1.28837, 36.795224, -1.242043), '0015': (36.795185, -1.28841, 36.841213, -1.242082), '0018': (36.703167, -1.334615, 36.749196, -1.288288), '0020': (36.795145, -1.334698, 36.841175, -1.28837), '0021': (36.841135, -1.334739, 36.887167, -1.28841), '0022': (30.033712, -1.947753, 30.079766, -1.901415), '0023': (30.079683, -1.947669, 30.125737, -1.901331), '0024': (30.125653, -1.947584, 30.171705, -1.901247), '0025': (30.033794, -1.994009, 30.079851, -1.947669), '0026': (30.079766, -1.993923, 30.125823, -1.947584), '0027': (30.125737, -1.993836, 30.171793, -1.947497), '0028': (30.885865, -17.792902, 30.934672, -17.746139), '0029': (30.934141, -17.793405, 30.982937, -17.746653), '0030': (30.982418, -17.793897, 31.031204, -17.747155), '0031': (31.030698, -17.794377, 31.079473, -17.747646), '0033': (31.127261, -17.795302, 31.176014, -17.748591), '0034': (30.885319, -17.83915, 30.934141, -17.792386), '0035': (30.933608, -17.839655, 30.982418, -17.792902), '0036': (30.981898, -17.840149, 31.030698, -17.793405), '0037': (31.03019, -17.84063, 31.078979, -17.793897), '0042': (30.981376, -17.8864, 31.03019, -17.839655), '0043': (31.02968, -17.886882, 31.078483, -17.840149), '0044': (31.077986, -17.887353, 31.126778, -17.84063), '0045': (31.126293, -17.887812, 31.175074, -17.841099), '0046': (30.884223, -17.931646, 30.933073, -17.88488), '0047': (30.932537, -17.932154, 30.981376, -17.885398), '0048': (30.980852, -17.93265, 31.02968, -17.885905), '0050': (31.077487, -17.933606, 31.126293, -17.886882), '0053': (30.931999, -17.978403, 30.980852, -17.931646), '0054': (30.980327, -17.978901, 31.029169, -17.932154), '0055': (31.028656, -17.979386, 31.077487, -17.93265), '0057': (31.125319, -17.980321, 31.174128, -17.933606), '0059': (17.035642, -22.597644, 17.086103, -22.550782), '0060': (28.154122, -15.42983, 28.202088, -15.383298), '0061': (28.201822, -15.429577, 28.249798, -15.383035), '0063': (28.29722, -15.429039, 28.345216, -15.382479), '0065': (28.392615, -15.428461, 28.440629, -15.381882), '0066': (28.440311, -15.428157, 28.488334, -15.381568), '0067': (28.154377, -15.47611, 28.202355, -15.429577), '0068': (28.202088, -15.475856, 28.250076, -15.429313), '0069': (28.249798, -15.475591, 28.297795, -15.429039), '0070': (28.297507, -15.475317, 28.345514, -15.428755), '0071': (28.345216, -15.475032, 28.393232, -15.428461), '0072': (28.392923, -15.474737, 28.440949, -15.428157), '0073': (28.440629, -15.474431, 28.488665, -15.427842), '0074': (32.479303, 0.35084, 32.525317, 0.397163), '0075': (32.525314, 0.350843, 32.571328, 0.397166), '0076': (32.571326, 0.350845, 32.61734, 0.397168), '0077': (32.617338, 0.350847, 32.663352, 0.39717), '0079': (32.525317, 0.304522, 32.57133, 0.350845), '0080': (32.571328, 0.304524, 32.617342, 0.350847), '0081': (32.61734, 0.304526, 32.663354, 0.350849), '0082': (32.479308, 0.2582, 32.525321, 0.304522), '0084': (32.57133, 0.258203, 32.617343, 0.304526), '0085': (32.617342, 0.258205, 32.663355, 0.304527), '0086': (32.47931, 0.211879, 32.525322, 0.258201), '0088': (32.571332, 0.211882, 32.617345, 0.258205), '0089': (32.617343, 0.211883, 32.663356, 0.258206), '0090': (-1.734157, 6.777424, -1.687709, 6.823852), '0091': (-1.687835, 6.777297, -1.641383, 6.823728), '0093': (-1.595193, 6.777029, -1.548735, 6.823467), '0094': (-1.548874, 6.776888, -1.502412, 6.82333), '0095': (-1.734277, 6.731121, -1.687835, 6.777547), '0096': (-1.687959, 6.730994, -1.641514, 6.777424),  ...

# %% [markdown]
# Now we are able to calculate the mean difference between the maximum and minimum coordinates of the existing bounding boxes.

# %%
from eotdl.tools import calculate_average_coordinates_distance

mean_long_diff, mean_lat_diff = calculate_average_coordinates_distance(bbox_by_existing_location)

print(f'The average Longitude difference is : {mean_long_diff}')
print(f'The average Latitude difference is : {mean_lat_diff}')
# Out:
# The average Longitude difference is : 0.04997205970149256
# The average Latitude difference is : 0.04664266865671639

# %% [markdown]
# ## Search new flooding events in existing locations

# %% [markdown]
# As said, another point of this use case is to improve the existing dataset with samples of new flooding events that have occured in the existing locations, between 2019 and 2022. Nevertheless, before generating the bounding boxes we need to make sure that we need all the new locations in the GeoDataFrame or we can drop some of them, if they are not needed. To do so, we need to check if any point in the new locations GeoDataFrame intersects with any existing bounding box, and that's why we keeped locations from Africa and Australia. If a point does not match with any existing location, we can drop it from the dataframe, as it is not necessary to maintain.
#
# First of all, we need to get the events located in Africa and Australia.

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
aoi = world[(world.continent == 'Africa') | (world.name == 'Australia')]

africa_australia_events = gpd.clip(flood_archive_gdf, aoi)

# %% [markdown]
# Now we can check if there have been any new flooding event in any of the existing location.

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')

    intersections = list()
    for id, bbox in bbox_by_existing_location.items():
        poly = gpd.GeoSeries(Polygon(box(*bbox))).set_crs(4326)
        intersection = africa_australia_events.intersects(poly)
        _gdf = africa_australia_events[intersection]
        n_intersections = len(_gdf.index)
        if n_intersections != 0:
            intersections.append(id)

print(f'There are a total number of {len(intersections)} new flooding events in the existing locations')
# Out:
# There are a total number of 0 new flooding events in the existing locations

# %% [markdown]
# Regarding to the results of the analysis, and according to the used archive, there have not been new flooding events in the existing locations. In this way, having contrasted the existing data with the data of new events we find that since there have been no new events in the locations of the dataset, it is not necessary to add more samples for said locations. So, we can delete the flooding events in Africa and Australia from the GeoDataFrame.

# %%
aoi = world[(world.continent.isin(['Europe', 'Asia']))]

flood_archive_gdf = gpd.clip(flood_archive_gdf, aoi)

# %% [markdown]
# ## Generate the bounding box for every new location

# %% [markdown]
# Now that we are sure that we have the needed GeoDataFrame and that the calculated bounding boxes seem to be correct, we have to generate a list with dictionaries for every new location, with the following information:
# * location_id `key`: we have to assign an unique ID to each new location, so we have to get the latest location ID from the dataset.
# * bounding_box `value 1`: generated bounding box of the new location.
# * time_interval `value 2`: time that the flooding event took.

# %%
from eotdl.tools import generate_new_locations_bounding_boxes

# Get the latest location ID from the existing locations
keys = [ int(k) for k in bbox_by_existing_location.keys()]
latest_id = max(keys)

# Get the dict for new locations
bbox_by_new_location = generate_new_locations_bounding_boxes(flood_archive_gdf,
                                                             (mean_long_diff, mean_lat_diff),
                                                             latest_id)
    
print(bbox_by_new_location)
# Out:
# {'337': {'bounding_box': [108.151014, -7.028221, 108.200986, -6.981579], 'time_interval': ('2021-05-24', '2021-05-28')}, '338': {'bounding_box': [107.855014, -6.879311, 107.904986, -6.832669], 'time_interval': ('2020-01-23', '2020-01-27')}, '339': {'bounding_box': [107.112014, -6.792461, 107.161986, -6.745819], 'time_interval': ('2021-03-25', '2021-03-26')}, '340': {'bounding_box': [107.261014, -6.730291, 107.310986, -6.683649], 'time_interval': ('2020-03-31', '2020-04-03')}, '341': {'bounding_box': [107.483014, -6.556781, 107.532986, -6.510139], 'time_interval': ('2020-01-01', '2020-01-09')}, '342': {'bounding_box': [107.038014, -6.481881, 107.087986, -6.435239], 'time_interval': ('2020-02-24', '2020-03-10')}, '343': {'bounding_box': [107.112014, -6.457251, 107.161986, -6.410609], 'time_interval': ('2021-02-19', '2021-02-22')}, '344': {'bounding_box': [105.679014, -4.981451, 105.728986, -4.934809], 'time_interval': ('2018-12-22', '2018-12-23')}, '345': {'bounding_box': [103.425014, -2.588061, 103.474986, -2.541419], 'time_interval': ('2020-11-19', '2020-11-23')}, '346': {'bounding_box': [101.842014, -2.140591, 101.891986, -2.093949], 'time_interval': ('2020-04-22', '2020-04-26')}, '347': {'bounding_box': [124.775014, -9.355111, 124.824986, -9.308469], 'time_interval': ('2021-04-03', '2021-04-10')}, '348': {'bounding_box': [118.544014, -8.520811, 118.593986, -8.474169], 'time_interval': ('2018-03-05', '2018-03-06')}, '349': {'bounding_box': [109.908014, -7.574511, 109.957986, -7.527869], 'time_interval': ('2021-01-11', '2021-01-13')}, '350': {'bounding_box': [109.488014, -7.289161, 109.537986, -7.242519], 'time_interval': ('2021-03-31', '2021-04-04')}, '351': {'bounding_box': [110.366014, -6.967531, 110.415986, -6.920889], 'time_interval': ('2021-02-22', '2021-02-28')}, '352': {'bounding_box': [121.810014, -4.010291, 121.859986, -3.963649], 'time_interval': ('2020-07-11', '2020-07-18')}, '353': {'bounding_box': [120.498014, -1.393521, 120.547986, -1.346879], 'time_interval': ('2020-03-05', '2020-03-15')}, '354': {'bounding_box': [120.226014, -1.033951, 120.275986, -0.987309], 'time_interval': ('2018-09-28', '2018-09-29')}, '355': {'bounding_box': [116.849014, -0.375462, 116.898986, -0.32882], 'time_interval': ('2020-05-22', '2020-05-30')}, '356': {'bounding_box': [113.422014, 3.109619, 113.471986, 3.156261], 'time_interval': ('2018-02-03', '2018-02-12')}, '357': {'bounding_box': [102.683014, -1.595701, 102.732986, -1.549059], 'time_interval': ('2018-12-05', '2018-12-10')}, '358': {'bounding_box': [99.961414, -0.03231, 100.011386, 0.014332], 'time_interval': ('2018-11-01', '2018-11-07')}, '359': {'bounding_box': [99.763414, 1.182739, 99.813386, 1.229381], 'time_interval': ('2020-11-04', '2020-11-09')}, '360': {'bounding_box': [100.159014, 1.926289, 100.208986, 1.972931], 'time_interval': ('2019-12-28', '2019-12-30')}, '361': {'bounding_box': [103.030014, 2.432779, 103.079986, 2.479421], 'time_interval': ('2020-06-20', '2020-06-25')}, '362': {'bounding_box': [102.312014, 3.635509, 102.361986, 3.682151], 'time_interval': ('2018-01-01', '2018-01-05')}, '363': {'bounding_box': [102.139014, 4.007769, 102.188986, 4.054411], 'time_interval': ('2021-01-01', '2021-01-12')}, '364': {'bounding_box': [96.992214, 4.233829, 97.042186, 4.280471], 'time_interval': ('2021-07-05', '2021-07-07')}, '365': {'bounding_box': [102.559014, 4.392049, 102.608986, 4.438691], 'time_interval': ('2019-11-30', '2019-12-06')}, '366': {'bounding_box': [101.842014, 5.464159, 101.891986, 5.510801], 'time_interval': ('2020-12-17', '2020-12-28')}, '367': {'bounding_box': [80.612014, 6.783069, 80.661986, 6.829711], 'time_interval': ('2018-10-02', '2018-10-04')}, '368': {'bounding_box': [80.488314, 6.845309, 80.538286, 6.891951], 'time_interval': ('2018-05-12', '2018-05-14')}, '369': {'bounding_box': [80.834714, 7.688129, 80.884686, 7.734771], 'time_interval': ('2018-12-22', '2018-12-26')}, '370': {'bounding_box': [80.809914, 7.712589, 80.859886, 7.759231], 'time_int ...

# %% [markdown]
# # Check available data from Sentinel Hub services

# %% [markdown]
# As said before, the main goal of this use case is to improve the existing SEN12-FLOOD dataset. In order to accomplish that, we are going to use DEM data and additional samples for recent floods and new areas.
#
# Firs of all, we need to configure the SH client from the EO-TDL library in order to provide [Sentinel Hub services](https://www.sentinel-hub.com/) such as satellite data collections, including Sentinel, Landsat, MODIS, DEM, and custom collections produced by users. It requires Sentinel Hub account, so please see [configuration instructions](https://sentinelhub-py.readthedocs.io/en/latest/configure.html) how to set up your configuration.

# %%
from eotdl.access import SHClient

sh_client_id = getenv('SH_CLIENT_ID')
sh_client_secret = getenv('SH_CLIENT_SECRET')

# %%
client = SHClient(sh_client_id=sh_client_id, 
                  sh_client_secret=sh_client_secret)

# %% [markdown]
# ## Sentinel-1 and Sentinel-2

# %%
from eotdl.tools import get_available_data_by_location

# %% [markdown]
# #### Sentinel-1

# %%
# %%time

sentinel_1_available_data, sentinel_1_locations_without_data = get_available_data_by_location(bbox_by_new_location, client, 'sentinel-1')

print(list(sentinel_1_available_data.values())[0])
print(f'There are a total number of {len(sentinel_1_available_data)} Sentinel-1 available images for new locations.')
# Out:
# {'bounding_box': [101.298014, 17.297079, 101.347986, 17.343721], 'time_interval': [('2021-09-26', '2021-09-26'), ('2021-09-23', '2021-09-23')]}
# There are a total number of 24 Sentinel-1 available images for new locations.
# CPU times: user 8.78 s, sys: 549 ms, total: 9.33 s
# Wall time: 1min 48s

# %% [markdown]
# #### Sentinel-2

# %%
# %%time

sentinel_2_available_data, sentinel_2_locations_without_data = get_available_data_by_location(bbox_by_new_location, client, 'sentinel-2')

print(list(sentinel_2_available_data.values())[0])
print(f'There are a total number of {len(sentinel_2_available_data)} Sentinel-2 available images for new locations.')
# Out:
# {'bounding_box': [87.936014, 23.775079, 87.985986, 23.821721], 'time_interval': [('2021-10-06', '2021-10-06'), ('2021-10-01', '2021-10-01')]}
# There are a total number of 51 Sentinel-2 available images for new locations.
# CPU times: user 9.25 s, sys: 577 ms, total: 9.83 s
# Wall time: 1min 46s

# %% [markdown]
# ## DEM

# %% [markdown]
# As DEM data is static, it does not make sense to check its availability in a time lapse or in a given location, as it is global.

# %% [markdown]
# # Download data from Sentinel Hub services

# %% [markdown]
# Now, we are able to create a request for each location. In order to efficiently download data for all requests in parallel, we are going to extract the download information and pass it to the EO-TDL client, which is able to download data.

# %% [markdown]
# ## Sentinel-1 and Sentinel-2

# %% [markdown]
# As said before, there is no need to download new Sentinel-1 and Sentinel-1 data for the existing locations, because of the fact that according to the downloaded flooding archive there have not occured new flooding events in those locations. So, we only need to download Sentinel imagery for the new locations from the archive.

# %% [markdown]
# #### Sentinel-1

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ROOT = getenv('ROOT_DOWNLOAD')

# %%
from eotdl.access import sentinel_1_download_parameters

sentinel_1_download_parameters.data_to_download = sentinel_1_available_data
# The path to the output folder can be changed, if needed
sentinel_1_download_parameters.data_folder = join(ROOT, 'sen12floods_s1_source') 

process_requests = client.request_bulk_data(sentinel_1_download_parameters)

# %%
# %%time

data = client.download_data(process_requests)

# %% [markdown]
# #### Sentinel-2

# %%
from eotdl.access import sentinel_2_download_parameters

sentinel_2_download_parameters.data_to_download = sentinel_2_available_data
sentinel_2_download_parameters.data_folder = join(ROOT, 'sen12floods_s2_source')

process_requests = client.request_bulk_data(sentinel_2_download_parameters)

# %%
# %%time

data = client.download_data(process_requests)

# %% [markdown]
# ## DEM

# %% [markdown]
# As we are going to download DEM data for all locations, both new and existing, we can merge the bounding boxes dictionaries into one and pass it to the request.

# %%
bbox_by_location = bbox_by_existing_location
bbox_by_location.update(bbox_by_new_location)

# %%
print(bbox_by_location)
# Out:
# {'0001': (-13.278254, 8.447033, -13.231551, 8.493532), '0004': (18.626057, -33.896767, 18.682633, -33.849575), '0005': (18.681385, -33.897797, 18.737935, -33.850628), '0006': (18.680135, -33.943938, 18.736717, -33.896767), '0007': (36.657265, -1.242004, 36.703289, -1.19568), '0009': (36.749236, -1.242082, 36.795262, -1.195757), '0010': (36.795224, -1.242121, 36.84125, -1.195795), '0011': (36.841213, -1.242158, 36.88724, -1.195832), '0012': (36.657223, -1.288288, 36.70325, -1.241963), '0013': (36.703209, -1.288329, 36.749236, -1.242004), '0014': (36.749196, -1.28837, 36.795224, -1.242043), '0015': (36.795185, -1.28841, 36.841213, -1.242082), '0018': (36.703167, -1.334615, 36.749196, -1.288288), '0020': (36.795145, -1.334698, 36.841175, -1.28837), '0021': (36.841135, -1.334739, 36.887167, -1.28841), '0022': (30.033712, -1.947753, 30.079766, -1.901415), '0023': (30.079683, -1.947669, 30.125737, -1.901331), '0024': (30.125653, -1.947584, 30.171705, -1.901247), '0025': (30.033794, -1.994009, 30.079851, -1.947669), '0026': (30.079766, -1.993923, 30.125823, -1.947584), '0027': (30.125737, -1.993836, 30.171793, -1.947497), '0028': (30.885865, -17.792902, 30.934672, -17.746139), '0029': (30.934141, -17.793405, 30.982937, -17.746653), '0030': (30.982418, -17.793897, 31.031204, -17.747155), '0031': (31.030698, -17.794377, 31.079473, -17.747646), '0033': (31.127261, -17.795302, 31.176014, -17.748591), '0034': (30.885319, -17.83915, 30.934141, -17.792386), '0035': (30.933608, -17.839655, 30.982418, -17.792902), '0036': (30.981898, -17.840149, 31.030698, -17.793405), '0037': (31.03019, -17.84063, 31.078979, -17.793897), '0042': (30.981376, -17.8864, 31.03019, -17.839655), '0043': (31.02968, -17.886882, 31.078483, -17.840149), '0044': (31.077986, -17.887353, 31.126778, -17.84063), '0045': (31.126293, -17.887812, 31.175074, -17.841099), '0046': (30.884223, -17.931646, 30.933073, -17.88488), '0047': (30.932537, -17.932154, 30.981376, -17.885398), '0048': (30.980852, -17.93265, 31.02968, -17.885905), '0050': (31.077487, -17.933606, 31.126293, -17.886882), '0053': (30.931999, -17.978403, 30.980852, -17.931646), '0054': (30.980327, -17.978901, 31.029169, -17.932154), '0055': (31.028656, -17.979386, 31.077487, -17.93265), '0057': (31.125319, -17.980321, 31.174128, -17.933606), '0059': (17.035642, -22.597644, 17.086103, -22.550782), '0060': (28.154122, -15.42983, 28.202088, -15.383298), '0061': (28.201822, -15.429577, 28.249798, -15.383035), '0063': (28.29722, -15.429039, 28.345216, -15.382479), '0065': (28.392615, -15.428461, 28.440629, -15.381882), '0066': (28.440311, -15.428157, 28.488334, -15.381568), '0067': (28.154377, -15.47611, 28.202355, -15.429577), '0068': (28.202088, -15.475856, 28.250076, -15.429313), '0069': (28.249798, -15.475591, 28.297795, -15.429039), '0070': (28.297507, -15.475317, 28.345514, -15.428755), '0071': (28.345216, -15.475032, 28.393232, -15.428461), '0072': (28.392923, -15.474737, 28.440949, -15.428157), '0073': (28.440629, -15.474431, 28.488665, -15.427842), '0074': (32.479303, 0.35084, 32.525317, 0.397163), '0075': (32.525314, 0.350843, 32.571328, 0.397166), '0076': (32.571326, 0.350845, 32.61734, 0.397168), '0077': (32.617338, 0.350847, 32.663352, 0.39717), '0079': (32.525317, 0.304522, 32.57133, 0.350845), '0080': (32.571328, 0.304524, 32.617342, 0.350847), '0081': (32.61734, 0.304526, 32.663354, 0.350849), '0082': (32.479308, 0.2582, 32.525321, 0.304522), '0084': (32.57133, 0.258203, 32.617343, 0.304526), '0085': (32.617342, 0.258205, 32.663355, 0.304527), '0086': (32.47931, 0.211879, 32.525322, 0.258201), '0088': (32.571332, 0.211882, 32.617345, 0.258205), '0089': (32.617343, 0.211883, 32.663356, 0.258206), '0090': (-1.734157, 6.777424, -1.687709, 6.823852), '0091': (-1.687835, 6.777297, -1.641383, 6.823728), '0093': (-1.595193, 6.777029, -1.548735, 6.823467), '0094': (-1.548874, 6.776888, -1.502412, 6.82333), '0095': (-1.734277, 6.731121, -1.687835, 6.777547), '0096': (-1.687959, 6.730994, -1.641514, 6.777424),  ...

# %%
from eotdl.access import dem_download_parameters

dem_download_parameters.data_to_download = bbox_by_location
# dem_download_parameters.data_folder = 'sen12floods_dem_source'
dem_download_parameters.data_folder = join(ROOT, 'sen12floods_dem_source')

process_requests = client.request_bulk_data(dem_download_parameters)

# %%
# %%time

data = client.download_data(process_requests)
# Out:
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
# ...
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# /Users/fran/miniconda3/envs/sen12floods/lib/python3.11/site-packages/sentinelhub/download/sentinelhub_client.py:87: SHRateLimitWarning: Download rate limit hit
#   warnings.warn("Download rate limit hit", category=SHRateLimitWarning)
# CPU times: user 58.1 s, sys: 9.58 s, total: 1min 7s
# Wall time: 3min 53s

# %% [markdown]
# # Format downloaded data

# %% [markdown]
# In order to maintain a logic structure and ensure that the set is diregible by the EO-TDL environment, we must make sure that the project structure is compatible with the `STAC` convention, as we are going to generate the metadata of every downloaded item and collection.
#
# The first task we have to do is extract every image band as a separate file.

# %%
from eotdl.curation import SHFolderFormatter

formatter = SHFolderFormatter(ROOT)

formatter.format_folders()

# %% [markdown]
# # Generate STAC metadata

# %%
from eotdl.curation.stac.stac import STACGenerator
from eotdl.curation.stac.assets import BandsAssetGenerator

# %%
OUTPUT = getenv('ROOT_OUTPUT')

stac_generator = STACGenerator(assets_generator=BandsAssetGenerator)

extensions = {'SAR': ('sar', 'proj', 'raster'), 'SENTINEL-2': ('eo', 'proj', 'raster'), 'DEM': ('proj', 'raster')}
bands = {'SAR': ('VV', 'VH'), 'SENTINEL-2': ('B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B09', 'B11', 'B12')}
collections = {'DEM': 'sen12floods_dem_source', 'SAR': 'sen12floods_s1_source', 'SENTINEL-2': 'sen12floods_s2_source'}

df = stac_generator.get_stac_dataframe(ROOT, collections=collections, bands=bands, extensions=extensions)
df.head()
# Out:
#                                                image       label  ix  \
# 0  /Users/fran/Documents/datasets/sen12floods-use...  SENTINEL-2   0
# 1  /Users/fran/Documents/datasets/sen12floods-use...  SENTINEL-2   0
# 2  /Users/fran/Documents/datasets/sen12floods-use...  SENTINEL-2   0
# 3  /Users/fran/Documents/datasets/sen12floods-use...  SENTINEL-2   0
# 4  /Users/fran/Documents/datasets/sen12floods-use...  SENTINEL-2   0
#
#                                           collection          extensions  \
# 0  /Users/fran/Documents/datasets/sen12floods-use...  (eo, proj, raster)
# 1  /Users/fran/Documents/datasets/sen12floods-use...  (eo, proj, raster)
# 2  /Users/fran/Documents/datasets/sen12floods-use...  (eo, proj, raster)
# 3  /Users/fran/Documents/datasets/sen12floods-use...  (eo, proj, raster)
# 4  /Users/fran/Documents/datasets/sen12floods-use...  (eo, proj, raster)
#
#                                                bands
# 0  (B01, B02, B03, B04, B05, B06, B07, B08, B09, ...
# 1  (B01, B02, B03, B04, B05, B06, B07, B08, B09, ...
# 2  (B01, B02, B03, B04, B05, B06, B07, B08, B09, ...
# 3  (B01, B02, B03, B04, B05, B06, B07, B08, B09, ...
# 4  (B01, B02, B03, B04, B05, B06, B07, B08, B09, ...

# %%
stac_generator.generate_stac_metadata(id='sen12-floods-eotdl',
                                      description='SEN12 FLOODS EO-TDL dataset',
                                      output_folder=OUTPUT)
# Out:
# Generating sen12floods_s2_source collection...
# 100%|██████████| 84/84 [00:04<00:00, 18.41it/s]
# Generating sen12floods_dem_source collection...
# 100%|██████████| 581/581 [00:00<00:00, 602.70it/s]
# Generating sen12floods_s1_source collection...
# 100%|██████████| 40/40 [00:00<00:00, 58.45it/s]
# Validating and saving catalog...
# Success!

# %% [markdown]
# #### Merge datasets

# %% [markdown]
# Now we have both datasets, we can merge them go get a single one.

# %%
from eotdl.curation import merge_stac_catalogs

# %%
SEN12FLOODS = join(getenv('ROOT_SEN12FLOODS'), 'catalog.json')
SEN12FLOODS_USE_CASE = join(getenv('ROOT_OUTPUT'), 'catalog.json')
SEN12FLOODS_OUTPUT = getenv('SEN12FLOODS_OUTPUT')

merge_stac_catalogs(SEN12FLOODS, 
                    SEN12FLOODS_USE_CASE,
                    destination=SEN12FLOODS_OUTPUT, 
                    keep_extensions=True)
# Out:
# Merging catalogs...: 0it [00:00, ?it/s]
# Merging catalogs...: 4it [00:28,  7.03s/it]
# Validating...
# Success

# %% [markdown]
# #### Add the ML-Extension

# %% [markdown]
# Now, we can add the ml-extension.

# %%
from eotdl.curation.stac.ml_dataset import add_ml_extension

catalog = join(SEN12FLOODS_OUTPUT, 'catalog.json')

add_ml_extension(catalog,
                 destination=SEN12FLOODS_OUTPUT,
                 name='SEN12-FLOODS EO-TDL Dataset',
                 tasks=['image classification'],
                 inputs_type=['satellite imagery'],
                 annotations_type='raster',
                 version='0.1.0')
# Out:
# Validating and saving...
# Success!

# %% [markdown]
# Ensure quality metrics

# %%
from eotdl.curation.stac.ml_dataset import MLDatasetQualityMetrics

MLDatasetQualityMetrics.calculate(catalog)
# Out:
# Looking for spatial duplicates...
# 11839it [00:04, 2455.12it/s]
# Calculating classes balance...
# 11839it [00:00, 253647.74it/s]
# Validating and saving...
# Success!
