# %%
import pandas as pd

tracker = pd.read_csv("jobs.csv")

tracker
# Out:
#                                              geometry  \
# 0   POLYGON ((7.59447026034365 51.352048235211875,...
# 1   POLYGON ((7.9313825299518275 51.56893150078220...
# 2   POLYGON ((9.070380399868506 51.6327019174455, ...
# 3   POLYGON ((8.635218214852326 52.12020246701559,...
# 4   POLYGON ((6.9561319036319 51.31003674526874, 6...
# 5   POLYGON ((8.098297466969036 51.8935886175864, ...
# 6   POLYGON ((8.584461109982 52.28925344114262, 8....
# 7   POLYGON ((8.946107043970517 51.96643697638922,...
# 8   POLYGON ((8.81338209817094 51.53073597914405, ...
# 9   POLYGON ((8.856842602218205 52.0521482714702, ...
# 10  POLYGON ((7.554517063546288 51.62367342069374,...
# 11  POLYGON ((6.500435025632354 51.350131353372014...
# 12  POLYGON ((6.236655008307854 51.05750652126743,...
# 13  POLYGON ((8.391437042090972 52.01128228489441,...
# 14  POLYGON ((7.8063003252379985 51.53903787562240...
# 15  POLYGON ((7.978680972916696 51.50315177972826,...
# ...
