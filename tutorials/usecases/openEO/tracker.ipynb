# %%
import pandas as pd

tracker = pd.read_csv("jobs-inference.csv")

tracker
# Out:
#    fid                                           geometry        crs  \
# 0  NaN  POLYGON ((25.6662734 58.63345021, 25.66637754 ...  EPSG:4326
# 1  NaN  POLYGON ((24.37944058 59.35179394, 24.37944933...  EPSG:4326
# 2  NaN  POLYGON ((24.3684642 58.85519494, 24.36851719 ...  EPSG:4326
#
#                 temporal_extent                                  id  \
# 0  ['2024-01-01', '2024-03-01']  j-2505161103024444b6e50166f8aeb88b
# 1  ['2024-01-01', '2024-03-01']  j-250516110319411dbdd4ebb4189c99ec
# 2  ['2024-01-01', '2024-03-01']  j-25051611033745fea98123d8907b6e1c
#
#   backend_name    status            start_time    running_start_time  \
# 0         cdse  finished  2025-05-16T11:03:02Z  2025-05-16T11:04:52Z
# 1         cdse   running  2025-05-16T11:03:19Z  2025-05-16T11:05:53Z
# 2         cdse   running  2025-05-16T11:03:37Z  2025-05-16T11:05:53Z
#
#                         cpu                       memory     duration
# ...
