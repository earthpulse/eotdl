# %%
import pandas as pd

tracker = pd.read_csv("jobs-inference.csv")

tracker
# Out:
#                                             geometry        crs  \
# 0  POLYGON ((26.52607801 57.53663606, 26.52618805...  EPSG:4326
# 1  POLYGON ((22.17822217 58.07140315, 22.17849956...  EPSG:4326
# 2  POLYGON ((23.34593042 58.53940151, 23.34591833...  EPSG:4326
#
#                 temporal_extent  \
# 0  ['2024-01-01', '2024-03-01']
# 1  ['2024-01-01', '2024-03-01']
# 2  ['2024-01-01', '2024-03-01']
#
#                             s1_weekly_statistics_url  \
# 0  https://api.eotdl.com/pipelines/68306c8ee2cef5...
# 1  https://api.eotdl.com/pipelines/68306c8ee2cef5...
# 2  https://api.eotdl.com/pipelines/68306c8ee2cef5...
#
#                             s2_weekly_statistics_url  \
# 0  https://api.eotdl.com/pipelines/68306c8ee2cef5...
# 1  https://api.eotdl.com/pipelines/68306c8ee2cef5...
# 2  https://api.eotdl.com/pipelines/68306c8ee2cef5...
#
#                         EC_hcat_n                                  id  \
# ...
