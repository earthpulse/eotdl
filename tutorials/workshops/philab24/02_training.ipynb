# %% [markdown]
# ## Training ML models

# %% [markdown]
# Once you have explored the repository and selected an appropriate training dataset, you can download it and train a model. In this notebook we will show an example of how to do so using the [EuroSAT](https://www.eotdl.com/datasets/EuroSAT-RGB) dataset, in its RGB version.
#
# > Remember that you can run this notebook in your cloud workspace to train a model in the cloud. If you require a GPU-powered machine, let us know though Discord and we will provide one!

# %%
from eotdl.datasets import download_dataset

path = download_dataset("EuroSAT-RGB", version=1, path="data", force=True)
path
# Out:
# 100%|██████████| 90.3M/90.3M [00:05<00:00, 17.7MiB/s]
# 100%|██████████| 1/1 [00:05<00:00,  5.65s/file]
# 'data/EuroSAT-RGB/v1'

# %%
# !unzip {path}/EuroSAT-RGB.zip -d data/train
# Out:
# Archive:  data/EuroSAT-RGB/v1/EuroSAT-RGB.zip
#    creating: data/train/EuroSAT-RGB/
#    creating: data/train/EuroSAT-RGB/Industrial/
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1743.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1273.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1117.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1121.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1641.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_259.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_435.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_674.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_905.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_238.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_631.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2292.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1952.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1980.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_524.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_689.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1967.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_305.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1184.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2193.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1015.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1532.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_146.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_962.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1543.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1328.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1721.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2024.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1233.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_94.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_910.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_364.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1096.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_512.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1291.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_59.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_124.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1899.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_78.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_448.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1920.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1434.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_421.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_125.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2216.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_265.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_354.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1327.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1104.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1923.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1312.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2486.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_239.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_212.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1978.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1378.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1535.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2037.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1881.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1797.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1739.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1225.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_665.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1710.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1708.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_253.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1754.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2359.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_40.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1491.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2281.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2471.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_767.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_496.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1049.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_807.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1376.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2479.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_850.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1124.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1955.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_594.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1469.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1073.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_299.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2367.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_153.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1959.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1522.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1694.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_419.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_882.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1215.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2062.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_233.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2063.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2394.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_412.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_702.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2372.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_778.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_835.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1898.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_241.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_480.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2073.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1578.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1503.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_719.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1430.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_316.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1056.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1531.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1698.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_228.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_993.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1722.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1106.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_770.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2025.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1808.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_557.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_258.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_148.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2283.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1798.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1568.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1672.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_150.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_891.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1366.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2272.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2267.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1635.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1561.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_718.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1844.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2408.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1510.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1342.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_408.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1914.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1265.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1358.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1719.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1685.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1637.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2492.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_83.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1857.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1474.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_352.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1403.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_832.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_568.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_915.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1256.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_242.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_780.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2088.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1985.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1638.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_225.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_717.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1497.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2052.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_338.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_164.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1645.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1045.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_367.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1204.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_733.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1806.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1099.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1871.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2368.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2429.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1781.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_54.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1865.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_550.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1093.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2068.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2022.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1460.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1511.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_115.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_371.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1292.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1895.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_467.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2104.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_101.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_773.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_373.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_37.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_311.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1906.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1605.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1199.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_917.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1479.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1247.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1820.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1238.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1748.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1950.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_294.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_276.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_889.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2250.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2010.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_195.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2352.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1109.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1068.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_757.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1540.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_84.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1934.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2204.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_10.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2119.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_206.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1499.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_627.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1960.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1338.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1762.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1615.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_342.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_406.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1858.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1917.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_655.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1187.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1033.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2491.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1915.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_525.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2136.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2269.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1796.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1827.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_972.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1966.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_953.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2344.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2466.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_273.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_920.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1193.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_138.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2026.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_974.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2449.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1697.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_399.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1890.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2233.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2017.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1562.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1311.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_57.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_468.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1468.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1862.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_2302.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_1621.jpg
#   inflating: data/train/EuroSAT-RGB/Industrial/Industrial_
#
# We can use the EuroSATRGB wrapper to pre-process the dataset, including the generation of classes, train/val/test splitting, etc. We plan to implement more wrappers for other datasets in the future, but feel free to contribute with your own (either to PytorchEO or any other library).

# %%
from pytorch_eo.datasets import EuroSATRGB

# do not set download to True since it will download the dataset from the original source and not EOTDL !

ds = EuroSATRGB(batch_size=25, verbose=True, path="data", download=False, data_folder='train/EuroSAT-RGB') 

ds.setup()
# Out:
# Number of images: 27000
# Training samples 16200
# Validation samples 5400
# Test samples 5400

# %%
ds.df
# Out:
#                                                    image  label
# 0      data/train/EuroSAT-RGB/AnnualCrop/AnnualCrop_4...      0
# 1      data/train/EuroSAT-RGB/AnnualCrop/AnnualCrop_2...      0
# 2      data/train/EuroSAT-RGB/AnnualCrop/AnnualCrop_1...      0
# 3      data/train/EuroSAT-RGB/AnnualCrop/AnnualCrop_1...      0
# 4      data/train/EuroSAT-RGB/AnnualCrop/AnnualCrop_1...      0
# ...                                                  ...    ...
# 26995    data/train/EuroSAT-RGB/SeaLake/SeaLake_1843.jpg      9
# 26996    data/train/EuroSAT-RGB/SeaLake/SeaLake_1516.jpg      9
# 26997    data/train/EuroSAT-RGB/SeaLake/SeaLake_2669.jpg      9
# 26998    data/train/EuroSAT-RGB/SeaLake/SeaLake_2734.jpg      9
# 26999     data/train/EuroSAT-RGB/SeaLake/SeaLake_243.jpg      9
#
# [27000 rows x 2 columns]

# %% [markdown]
# This dataset contains 27000 Sentinel 2 images classified in 10 categories.

# %%
ds.num_classes, ds.classes
# Out:
# (10,
#  ['AnnualCrop',
#   'Forest',
#   'HerbaceousVegetation',
#   'Highway',
#   'Industrial',
#   'Pasture',
#   'PermanentCrop',
#   'Residential',
#   'River',
#   'SeaLake'])

# %%
import matplotlib.pyplot as plt

batch = next(iter(ds.train_dataloader()))
imgs, labels = batch['image'], batch['label']

fig = plt.figure(figsize=(10, 10))
for i, (img, label) in enumerate(zip(imgs, labels)):
    ax = plt.subplot(5, 5, i + 1)
    ax.imshow(img.permute(1, 2, 0))
    ax.set_title(ds.classes[label.item()])
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# We will train a neural network for the task of Image classification.

# %%
import torch 
from pytorch_eo.tasks.classification import ImageClassification

task = ImageClassification(num_classes=ds.num_classes)

sample_inputs = torch.randn(8, 3, 224, 224)
output = task(sample_inputs)
output.shape
# Out:
# torch.Size([8, 10])

# %%
import lightning as L

trainer = L.Trainer(
    accelerator="cuda",
    devices=1,
    max_epochs=5,
	enable_checkpointing=False,
	limit_train_batches=50,
	limit_val_batches=50,
)

trainer.fit(task, ds)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/juan/miniconda3/envs/peo/lib/python3.8/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:75: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Missing logger folder: /home/juan/Desktop/eotdl/tutorials/workshops/philab24/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Number of images: 27000
# Training samples 16200
# Validation samples 5400
# Test samples 5400
#   | Name    | Type               | Params
# -----------------------------------------------
# 0 | model   | ResNet             | 11.2 M
# 1 | loss_fn | CrossEntropyLoss   | 0
# 2 | acc     | MulticlassAccuracy | 0
# -----------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.727    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/juan/miniconda3/envs/peo/lib/python3.8/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# /home/juan/miniconda3/envs/peo/lib/python3.8/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=5` reached.

# %% [markdown]
# Once the model is trained you can evaluate it using some test data.

# %%
from tqdm import tqdm 

task.eval()
acc = 0
with torch.no_grad():
	for batch in tqdm(ds.test_dataloader()):
		output = task(batch['image'])
		acc += (output.argmax(1) == batch['label']).sum().item()

print("test accuracy: ", f'{acc}/{len(ds.test_dataloader().dataset)}')
# Out:
# 100%|██████████| 216/216 [00:06<00:00, 35.37it/s]
# test accuracy:  2427/5400

# %%
# extract batch from test dataloader

batch = next(iter(ds.test_dataloader(shuffle=True, batch_size=25)))
imgs, labels = batch['image'], batch['label']

# compute predictions

preds = task.predict(batch)
preds = torch.argmax(preds, axis=1)

# visualize predictions

fig = plt.figure(figsize=(10, 10))
for i, (img, label, pred) in enumerate(zip(imgs, labels, preds)):
	ax = plt.subplot(5, 5, i + 1)
	ax.imshow(img.permute(1,2,0))
	gt = ds.classes[label.item()]
	pred = ds.classes[pred.item()]
	ax.set_title(gt, color="green" if gt == pred else 'red')
	ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# And export it to later ingestion to the EOTDL. You can choose your preferred export method, here we use [ONNX]().

# %%
# !pip install onnx onnxruntime

# %%
filepath = "data/model.onnx"
task.to_onnx(filepath, imgs, export_params=True, dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}})
# Out:
# /home/juan/miniconda3/envs/peo/lib/python3.8/site-packages/torch/onnx/utils.py:2029: UserWarning: Provided key input for dynamic axes is not a valid input/output name
#   warnings.warn(
# /home/juan/miniconda3/envs/peo/lib/python3.8/site-packages/torch/onnx/utils.py:2029: UserWarning: Provided key output for dynamic axes is not a valid input/output name
#   warnings.warn(
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
import onnxruntime
import numpy as np

ort_session = onnxruntime.InferenceSession(filepath)
input_name = ort_session.get_inputs()[0].name
ort_inputs = {input_name: imgs.numpy()}
ort_outs = ort_session.run(None, ort_inputs)
ort_outs[0].shape
# Out:
# (25, 10)

# %%
acc = 0
for batch in tqdm(ds.test_dataloader()):
	ort_inputs = {input_name: batch['image'].numpy()}
	ort_outs = ort_session.run(None, ort_inputs)
	acc += np.sum((ort_outs[0].argmax(1) == batch['label'].numpy()))

print("test accuracy: ", f'{acc}/{len(ds.test_dataloader().dataset)}')
# Out:
# 100%|██████████| 216/216 [00:05<00:00, 37.24it/s]
# test accuracy:  2427/5400

# %% [markdown]
# You will learn how to ingest this model to EOTDL in the nex notebook.
#
# This has been a fast and easy example on how to train an ML model with a datasets downloaded from EOTDL. It is not our goal to provide a complete tutorial on how to train a model, but rather to show how to use the EOTDL. If you want to learn more about AI and training deep neural networks, we encourage you to explore the [PytorchEO](https://github.com/earthpulse/pytorchEO) library, and even contribute with more datasets, tasks, models and wrappers. We challenge you to train a better model!

# %% [markdown]
# ## Discussion and Contribution opportunities

# %% [markdown]
# Feel free to ask questions now (live or through Discord) and make suggestions for future improvements.
#
# - What would you like to see in the EOTDL concerning training?
# - What are the main challenges you face when training ML models with EO data?
# - What are the main datasets you would like to see in the EOTDL?
# - What are the main tasks you would like to see implemented?
# - What are the main models you would like to see implemented?
# - What are the frameworks you would like to have wrappers for?
