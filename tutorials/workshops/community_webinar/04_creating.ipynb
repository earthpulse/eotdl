# %% [markdown]
# # Creating datasets

# %% [markdown]
# You can leverage EOTDL tools to create a brand new dataset. Here we cover:
#
# 1. **Data exploration**: given an area of interest, query available sentinel data for your dataset.
# 2. **Data access**: download your data for creating the dataset.
# 3. **Data preparation**: clean your data, perform feature engineering, data analysis, labelling, etc.
#
# Once your dataset is ready, you can ingest it to the EOTDL like we have seen in the previous notebook and start working with it as any other dataset in the repository.

# %% [markdown]
# ## Exploration

# %% [markdown]
# First of all, let's explore the area of interest that we have selected for this workshop. In this case we have chosen the [Boadella reservoir](https://es.wikipedia.org/wiki/Embalse_de_Darnius_Boadella) in Catalonia, Spain, which geometry is in the data folder as `webinar_data/boadella.geojson`. Here we use [leafmap](https://leafmap.org/) for visualizing it, but feel free to use your preferred solution.

# %%
# !pip install leafmap

# %%
import leafmap
import geopandas as gpd

in_geojson = "webinar_data/boadella.geojson"
gdf = gpd.read_file(in_geojson)

centroid_coords = gdf["geometry"].centroid
centroid = [
    centroid_coords.y.values[0],
    centroid_coords.x.values[0],
]  # We are going to use the centroid later

m = leafmap.Map(center=centroid, zoom=13)
m.add_geojson(in_geojson, layer_name="Boadella reservoir")
m
# Out:
# Map(center=[42.347577325903515, 2.815024677909404], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %% [markdown]
# When creating AI-Ready datasets it is usual to work at a fixed resolution. You can either retrieve full scenes and cut patches, or use EOTDL functionality to generate appropriate bounding boxes. With the aim that all the images in the dataset have 512x512 pixels, we are going to use the centroid that we extracted before from the geoJSON and generate a bounding box that will result in a 512x512 pixels image at 10m resolution since we are going to use Sentinel data.

# %%
from eotdl.tools import bbox_from_centroid

boadella_bbox = bbox_from_centroid(
    x=centroid[0], y=centroid[1], pixel_size=10, width=512, height=512
)
boadella_bbox
# Out:
# [2.784022776094264, 42.324467423078886, 2.8460492944612303, 42.37067879125418]

# %% [markdown]
# Let's visualize the bounding box on a map!

# %%
from eotdl.tools import bbox_to_polygon

# Create a polygon from the bbox
boadella_polygon = bbox_to_polygon(boadella_bbox)
# Create a GeoDataFrame from the polygon
gdf = gpd.GeoDataFrame(geometry=[boadella_polygon])
# Save the bounding box as a geoJSON file, if needed
gdf.to_file(
    "webinar_data/boadella_bbox.geojson", driver="GeoJSON"
)  # Uncomment to save the bbox as a GeoJSON file

m.add_geojson("webinar_data/boadella_bbox.geojson", layer_name="Boadella bbox")
m
# Out:
# Map(bottom=776066.0, center=[42.347577325903515, 2.815024677909404], controls=(ZoomControl(options=['position'…

# %% [markdown]
# Now that he have our desired bounding box we can look for available Sentinel-2 imagery on it. This can be done through the EOTDL.
#
# First, we can look for which Sentinel sensors are supported in the EOTDL

# %%
from eotdl.access import SUPPORTED_COLLECTION_IDS

SUPPORTED_COLLECTION_IDS
# Out:
# ['sentinel-1-grd',
#  'sentinel-2-l1c',
#  'sentinel-2-l2a',
#  'dem',
#  'hls',
#  'landsat-ot-l2',
#  'landsat-ot-l1',
#  'landsat-tm-l2',
#  'landsat-tm-l1']

# %% [markdown]
# If we want to look for available Sentinel-2 imagery in our AoI, we must define a range of dates in which to search for the images. We have already defined a time interval for this workshop, which is in the `workshop_data/dates.csv` file.

# %%
import csv

dates = list()
with open("webinar_data/dates.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        dates.append(row[0])
dates.sort()

dates[:5]
# Out:
# ['2020-01-13', '2020-01-28', '2020-02-02', '2020-06-21', '2020-09-14']

# %% [markdown]
# Although we have the specific dates, we are going to search for the entire time interval, just as a demonstrator.

# %% [markdown]
# > We use Sentinle Hub under the hood, so you will need appropriate credentials. You can generate them automatically from your user [profile](https://www.eotdl.com/profile) by accepting the terms and conditions. When you login to the EOTDL, via the library or CLI, we retrieve and store this information for you, so you don't need to worry about it. However there are a couple of gotchas: <br><br> 1. If you already have a Sentinel HUB account with the same email as your EOTDL account, you will need to retrieve the credentials from Sentinel Hub Dashboard and set them as env variables. <br> 2. The credentials generated via EOTDL may expire after some time (we are working on this). If this happens, let us know in Discord to fix the issue. <br><br> In any case, you can provide your own credentials by setting the appropriate environment variables: `SH_CLIENT_ID` and `SH_CLIENT_SECRET`.

# %%
from eotdl.access import search_sentinel_imagery

time_interval = (dates[0], dates[-1])

r = search_sentinel_imagery(time_interval, boadella_bbox, "sentinel-2-l2a")
response = list(r)
response[:5]
# Out:
# [{'id': 'S2B_MSIL2A_20220601T103629_N0400_R008_T31TDG_20220601T135543',
#   'properties': {'datetime': '2022-06-01T10:49:26Z', 'eo:cloud_cover': 0.23}},
#  {'id': 'S2B_MSIL2A_20220601T103629_N0400_R008_T31TDH_20220601T135543',
#   'properties': {'datetime': '2022-06-01T10:49:14Z', 'eo:cloud_cover': 12.82}},
#  {'id': 'S2A_MSIL2A_20220527T103631_N0400_R008_T31TDG_20220527T183616',
#   'properties': {'datetime': '2022-05-27T10:49:34Z', 'eo:cloud_cover': 85.6}},
#  {'id': 'S2A_MSIL2A_20220527T103631_N0400_R008_T31TDH_20220527T183616',
#   'properties': {'datetime': '2022-05-27T10:49:19Z', 'eo:cloud_cover': 30.42}},
#  {'id': 'S2B_MSIL2A_20220522T103629_N0400_R008_T31TDG_20220522T124154',
#   'properties': {'datetime': '2022-05-22T10:49:27Z', 'eo:cloud_cover': 12.99}}]

# %% [markdown]
# They make sense, as the [revisit time](https://docs.sentinel-hub.com/api/latest/data/sentinel-2-l2a/#basic-facts) for Sentinel-2 is 5 days.
#
# As a final step, let's check the number of dates with available images.

# %%
print(len(response))
# Out:
# 342

# %% [markdown]
# To sum up this section, we have explored our AoI, generated a bounding box and a time interval in which to look for imagery and searched for Sentinel-2 imagery.

# %% [markdown]
# ## Download

# %% [markdown]
# The next step is to download the images. On the one hand, we can download image by image, as follows.

# %%
from eotdl.access import download_sentinel_imagery

first_date = dates[0]

download_sentinel_imagery(
    "data/sentinel_2", first_date, boadella_bbox, "sentinel-2-l2a"
)

# %% [markdown]
# On the other hand, we can search and download all available images within a time interval, as follows. This is the recommended way for a bulk download, but it has the drawback that we cannot control the quality of the images, as for example know their cloud cover.

# %%
demostration_dates = (dates[0], dates[2])

download_sentinel_imagery(
    output="data/sentinel_2",
    time_interval=demostration_dates,
    bounding_box=boadella_bbox,
    collection_id="sentinel-2-l2a",
)

# %% [markdown]
# That's all! We have downloaded the images for our dataset. Let's check them!

# %%
from glob import glob

rasters = glob("data/sentinel_2/*.tiff")
rasters[:5]
# Out:
# ['data/sentinel_2/sentinel-2-l2a_2020-01-28.tiff',
#  'data/sentinel_2/sentinel-2-l2a_2020-02-02.tiff',
#  'data/sentinel_2/sentinel-2-l2a_2020-01-13.tiff',
#  'data/sentinel_2/sentinel-2-l2a_2020-01-18.tiff',
#  'data/sentinel_2/sentinel-2-l2a_2020-01-23.tiff']

# %% [markdown]
# One last optional step is to rename the images and cleanup the directory.

# %%
files = glob('data/sentinel_2/*')
for file in files:
    new_file_name = file.replace('sentinel-2-l2a', 'Boadella').replace('.tiff', '.tif')
    ! mv $file $new_file_name

# !rm -r data/sentinel_2/*.json

# %%
# !ls data/sentinel_2
# Out:
# Boadella_2020-01-13.tif Boadella_2020-01-23.tif Boadella_2020-02-02.tif
# Boadella_2020-01-18.tif Boadella_2020-01-28.tif

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# As the final step towards creating our training dataset, we need to make the data AI-Ready. There are multitude of tasks that can be performed here, such as:
#
# - **Data cleaning**: remove corrupted images, remove images with too much cloud cover, etc.
# - **Feature engineering**: calculate vegetation indices, calculate statistics, etc.
# - **Data analysis**: plot time series, plot histograms, etc.
# - **Labelling**: create labels for the images, etc.
#
# For each one, feel free to use your favourite tools. Here we are going to demonstrate labelling using [SCANEO](https://github.com/earthpulse/scaneo).
#
# SCANEO is a labelling web application that allows tagging satellite images (to identify, e.g., objects present, terrain types, etc.) in an easy and fast way. The service provided by SCANEO is vital since it is necessary to prepare the satellite data so that it can be processed by neural networks, enabling active learning.
#
# Before running the web interface, we need to make sure we have the `scaneo` package installed in our machine and, if not, install it.

# %%
# !pip install scaneo

# %% [markdown]
# You can run `scaneo` with the following options

# %%
# !scaneo --help
# Out:
#
#  Usage: scaneo [OPTIONS]
#
# ╭─ Options ────────────────────────────────────────────────────────────────────╮
# │ --port                -p      INTEGER  Port to run the server on             │
# │                                        [default: 8000]                       │
# │ --host                -h      TEXT     Host to run the server on             │
# │                                        [default: localhost]                  │
# │ --workers             -w      INTEGER  Number of workers to run the server   │
# │                                        on                                    │
# │                                        [default: None]                       │
# │ --version             -v               Print the version and exit            │
# │ --install-completion                   Install completion for the current    │
# │                                        shell.                                │
# │ --show-completion                      Show completion for the current       │
# │                                        shell, to copy it or customize the    │
# │                                        installation.                         │
# │ --help                                 Show this message and exit.           │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# You can run `scaneo` by opening a terminal and running:
#
# ```
# scaneo
# ```
#
# Then, you can then access the web interface at `http://localhost:8000`.
#
# > You can change the host and port with `scaneo --host 0.0.0.0 --port 8000`.

# %%
# !scaneo --host 0.0.0.0 --port 8000
# Out:
# Running command: uvicorn api:app --port 8000 --host 0.0.0.0 --app-dir /Users/juan/Desktop/eotdl/.venv/lib/python3.12/site-packages/scaneo
# INFO:     Started server process [72156]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:59859 - "GET / HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:59859 - "GET /_plugins HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59860 - "GET /_plugins HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59860 - "GET /_app/immutable/nodes/8.k7IdZTDK.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59860 - "GET /_models HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59859 - "GET /_plugins HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59859 - "GET /_campaigns HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59860 - "GET /_plugins HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59860 - "GET /_models HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59859 - "GET /_plugins HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59863 - "GET /_campaigns HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59864 - "GET /_plugins HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59864 - "GET /_models HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59863 - "GET /images/28eb3001-d734-45d6-93ff-a09228fc6ccd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59866 - "GET /labels/28eb3001-d734-45d6-93ff-a09228fc6ccd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59867 - "GET /_campaigns/28eb3001-d734-45d6-93ff-a09228fc6ccd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59868 - "GET /_plugins HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59868 - "GET /annotations/110 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59863 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59866 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59869 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59864 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59867 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59868 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59866 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59863 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59866 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59869 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59864 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59869 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59863 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59866 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59867 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59868 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /annotations/114 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8320/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8319/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8319/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8320/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8319/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8321/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8318/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8321/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8318/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8320/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8321/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8319/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8321/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8320/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8318/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-13.tif/14/8318/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /annotations/113 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8319/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8319/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8319/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8320/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8320/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8318/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8318/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8321/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8318/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8321/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8321/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8318/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8319/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8320/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8320/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-28.tif/14/8321/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /annotations/112 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8319/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8320/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8320/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8319/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8319/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8318/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8318/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8321/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8321/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8321/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8320/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8319/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8320/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8318/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8318/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-18.tif/14/8321/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /annotations/111 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8319/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8320/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8319/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8320/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8319/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8320/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8320/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8321/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8319/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8318/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8321/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8321/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8318/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8321/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8318/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-01-23.tif/14/8318/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /annotations/110 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59870 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59874 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6059.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59871 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8320/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59872 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8321/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59875 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6060.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8319/6062.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59873 - "GET /images/data/sentinel_2/Boadella_2020-02-02.tif/14/8318/6061.png?stretch=0,4000&bands=4,3,2&palette=viridis HTTP/1.1" 200 OK
# ^C
# INFO:     Finished server process [72156]
# ERROR:    Traceback (most recent call last):
#   File "/Users/juan/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/juan/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "uvloop/loop.pyx", line 1512, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1505, in uvloop.loop.Loop.run_until_complete
#   File "uvloop/loop.pyx", line 1379, in uvloop.loop.Loop.run_forever
#   File "uvloop/loop.pyx", line 557, in uvloop.loop.Loop._run
#   File "uvloop/loop.pyx", line 476, in uvloop.loop.Loop._on_idle
#   File "uvloop/cbhandles.pyx", line 83, in uvloop.loop.Handle._run
#   File "uvloop/cbhandles.pyx", line 63, in uvloop.loop.Handle._run
#   File "/Users/juan/Desktop/eotdl/.venv/lib/python3.12/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juan/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/Users/juan/Desktop/eotdl/.venv/lib/python3.12/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/Users/juan/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/juan/Desktop/eotdl/.venv/lib/python3.12/site-packages/starlette/routing.py", line 699, in lifespan
#     await receive()
#   File "/Users/juan/Desktop/eotdl/.venv/lib/python3.12/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juan/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError

# %% [markdown]
# Your annotations will be stored alongside the images as GeoJSON files containig the segmentation masks as multipolygons, bounding boxes for detection tasks or classification labels.

# %%
# !ls data/sentinel_2/*.geojson
# Out:
# data/sentinel_2/Boadella_2020-02-02.geojson

# %% [markdown]
# Once your data is ready you can ingest it to EOTDL like we have seen in the previous notebook and start working with it as any other dataset in the repository.

# %%
text = """---
name: Boadella-community-webinar
authors: 
  - Juan B. Pedro
license: free
source: https://github.com/earthpulse/eotdl/blob/develop/tutorials/workshops/community-webinar/04_creating.ipynb
---

# Boadella-community-webinar

This is a toy dataset created during the community webinar.
"""∫

with open("data/sentinel_2/README.md", "w") as outfile:
    outfile.write(text)

# %%
from eotdl.datasets import ingest_dataset

ingest_dataset("data/sentinel_2")
# Out:
# Ingesting folder
# Ingesting directory: data/sentinel_2
# Preparing files: 100%|██████████| 8/8 [00:00<00:00, 916.16it/s]
# Ingesting files: 100%|██████████| 8/8 [00:04<00:00,  1.65it/s]
# PosixPath('data/sentinel_2/catalog.parquet')

# %% [markdown]
# If you add more images or labels to the dataset, you can re-upload and a new version will be automatically generated.

# %% [markdown]
# ## Learn more with our use cases

# %% [markdown]
# There is much more on EOTDL and SCANEO for creating and labelling datasets as well as training models in the [EOTDL use cases](https://github.com/earthpulse/eotdl/tree/main/tutorials/usecases) section.

# %% [markdown]
# ## Discussion and Contribution opportunities

# %% [markdown]
# Feel free to ask questions now (live or through Discord) and make suggestions for future improvements.
#
# - What features concerning data exploration would you like to see?
# - What other features concerning data download would you like to see?
# - What features and tools concerning data preparation would you like to see?
# - What does your typical workflow look like?
# - Do you already use any labelling tool?
# - What does you ideal labelling tool looks like?
