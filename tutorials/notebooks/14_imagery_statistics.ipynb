# %% [markdown]
# # Imagery statistics

# %% [markdown]
# To obtain more information about an image before saving it or if we want to perform various analyses, we can use EO-TDL statistics. Statistics returns aggregated statistical values of satellite data instead of entire images.

# %% [markdown]
# Uncomment the following line to install eotdl if needed.

# %%
#!pip install eotdl

# %% [markdown]
# First, let's define the time period and the location we want to use in the analysis.

# %%
dates = ("2023-01-01", "2024-01-01")
bounding_box = (15.695686,46.423659,15.722809,46.439513)

# %% [markdown]
# We select EO-TDL's Sentinel-2 Level-2A data collection, get default parameters and set the maximum cloud coverage and the aggregation interval (ISO 8601 duration format).

# %%
from eotdl.access import (
    DATA_COLLECTION_ID,
    get_default_parameters
)

parameters = get_default_parameters(DATA_COLLECTION_ID.SENTINEL_2_L2A)
parameters.MAX_CLOUD_COVERAGE = 0.2
parameters.AGGREGATION_INTERVAL = "P1D"

# %% [markdown]
# We also need to define the evalscript, in which we specify what value each pixel will represent. Based on this, the statistics will be calculated. In our case, the pixel will represent the NDVI value, which is calculated from the red and near-infrared spectral bands.

# %%
evalscript = """ 
//VERSION=3

function setup() {
  return {
    input: [
      {
        bands: [
          "B04",
          "B08",
          "dataMask"
        ]
      }
    ],
    output: [
      {
        id: "ndvi",
        bands: 1
      },
      {
        id: "dataMask",
        bands: 1
      }
    ]
  }
}

function evaluatePixel(sample) {
    let ndvi = (sample.B08 - sample.B04) / (sample.B08 + sample.B04);
  
    return {
      ndvi: [ndvi],
      dataMask: [sample.dataMask]
    };
}
"""

# %% [markdown]
# We now request statistical data over the defined time and location, and store the results in a pandas DataFrame.

# %%
from eotdl.access import get_statistics

df = get_statistics(dates, bounding_box, parameters, evalscript)
df
# Out:
#    interval_from interval_to  ndvi_B0_min  ndvi_B0_max  ndvi_B0_mean  \
# 0     2023-02-04  2023-02-05    -0.219973     1.000000      0.431946
# 1     2023-02-09  2023-02-10    -0.062900     0.907060      0.402182
# 2     2023-02-14  2023-02-15    -0.010844     0.887971      0.393748
# 3     2023-02-21  2023-02-22    -0.014724     0.908552      0.378011
# 4     2023-03-16  2023-03-17     0.012716     0.955439      0.417945
# 5     2023-03-21  2023-03-22    -0.010157     0.909865      0.395584
# 6     2023-04-27  2023-04-28    -0.131034     0.919414      0.400017
# 7     2023-05-22  2023-05-23     0.018164     0.920904      0.363502
# 8     2023-05-25  2023-05-26     0.053291     0.889489      0.314786
# 9     2023-06-09  2023-06-10     0.006547     0.929953      0.455088
# 10    2023-06-16  2023-06-17     0.004192     0.917770      0.488814
# 11    2023-06-19  2023-06-20     0.023403     0.922405      0.527737
# 12    2023-06-26  2023-06-27     0.024655     0.915315      0.613772
# 13    2023-06-29  2023-06-30    -0.003423     0.934620      0.680968
# 14    2023-07-09  2023-07-10    -0.007456     0.930257      0.723315
# 15    2023-07-11  2023-07-12     0.055221     0.905150      0.705501
# 16    2023-07-14  2023-07-15     0.030637     0.934027      0.748365
# 17    2023-07-16  2023-07-17     0.016332     0.918737      0.724404
# 18    2023-07-29  2023-07-30     0.007016     0.940032      0.767399
# 19    2023-08-13  2023-08-14     0.009002     0.920215      0.744799
# 20    2023-08-15  2023-08-16     0.001490     0.916084      0.733978
# 21    2023-08-20  2023-08-21     0.005966     0.899709      0.723508
# 22    2023-09-02  2023-09-03     0.002538     0.908079      0.682520
# 23    2023-09-04  2023-09-05    -0.018730     0.910119      0.665300
# 24    2023-09-07  2023-09-08    -0.012584     0.905120      0.627046
# 25    2023-09-09  2023-09-10    -0.017893     0.885932      0.587978
# 26    2023-09-12  2023-09-13    -0.037062     0.894378      0.548272
# 27    2023-09-29  2023-09-30     0.007364     0.882153      0.386668
# 28    2023-10-02  2023-10-03     0.015126     0.883525      0.367319
# 29    2023-10-14  2023-10-15    -0.016913     0.891491      0.320610
# 30    2023-11-01  2023-11-02    -0.013714     0.944921      0.430644
# 31    2023-11-08  2023-11-09    -0.048689     0.956989      0.472770
# 32    2023-11-18  2023-11-19    -0.059194     0.936655      0.400569
# 33    2023-11-23  2023-11-24    -0.036797     0.961757      0.481433
# 34    2023-12-03  2023-12-04    -0.181102     1.000000      0.484983
# 35    2023-12-18  2023-12-19    -0.056007     0.933551      0.475450
#
#     ndvi_B0_stDev  ndvi_B0_sampleCount  ndvi_B0_noDataCount
# 0        0.271186                36846                    0
# 1        0.243096                36846                    0
# 2        0.240365                36846                    0
# 3        0.235870                36846                    0
# 4        0.270603                36846                    0
# 5        0.267268                36846                    0
# 6        0.256147                36846                    0
# 7        0.280084                36846                    0
# 8        0.237041                36846                    0
# 9        0.191851                36846                    0
# 10       0.169540                36846                    0
# 11       0.161032                36846                    0
# 12       0.175046                36846                    0
# 13       0.195467                36846                    0
# 14       0.240747                36846                    0
# 15       0.217360                36846                    0
# 16       0.234846                36846                    0
# 17       0.234468                36846                    0
# 18       0.214495                36846                    0
# 19       0.210999                36846                    0
# 20       0.209538                36846                    0
# 21       0.194204                36846                    0
# 22       0.160629                36846                    0
# 23       0.163745                36846                    0
# 24       0.159736                36846                    0
# 25       0.153635                36846                    0
# 26       0.153801                36846                    0
# 27       0.172679                36846                    0
# 28       0.179110                36846                    0
# 29       0.182941                36846                    0
# 30       0.220590                36846                    0
# 31       0.239253                36846                    0
# 32       0.208902                36846                    0
# 33       0.260399                36846                    0
# 34       0.246978                36846                    0
# 35       0.228814                36846                    0

# %% [markdown]
# We visualize the mean NDVI values over time, along with standard deviation as a shaded band.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15, 8))
ax.set_title("NDVI Time Series via EO-TDL Statistics")
ax.set_ylabel("NDVI mean")
ax.set_xlabel("Date")

# Plot NDVI mean
df.plot(ax=ax, x="interval_from", y="ndvi_B0_mean", color="blue", label="NDVI Mean")

# Fill between +/- 1 standard deviation
ax.fill_between(
    df.interval_from.values,
    df["ndvi_B0_mean"] - df["ndvi_B0_stDev"],
    df["ndvi_B0_mean"] + df["ndvi_B0_stDev"],
    color="blue",
    alpha=0.1,
    label="Standard Deviation"
)

ax.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# This NDVI time series analysis, using EO-TDL Statistics, offers a clear view of vegetation trends in a selected region. NDVI is a reliable indicator of vegetation health, and EO-TDL's cloud-aware, interval-based approach allows for clean, interpretable time-series generation from remote sensing data.

# %%
from eotdl.access import download_sentinel_imagery, DATA_COLLECTION_ID
import rasterio as rio
from glob import glob
import matplotlib.pyplot as plt

date = "2023-06-29"

download_sentinel_imagery("test", date, bounding_box, DATA_COLLECTION_ID.SENTINEL_2_L2A)

raster = glob("test/*.tiff")[0]
x = rio.open(raster).read()
rgb = x[[3, 2, 1], ...] / 4000
plt.imshow(rgb.transpose(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0255..1.026].
