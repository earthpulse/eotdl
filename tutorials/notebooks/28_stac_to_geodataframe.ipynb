# %% [markdown]
# # STAC to GeoDataFrame

# %% [markdown]
# Since STAC items are `.json` files they could be converted directly into a `GeoPandas` `GeoDataFrame`. However, this way you lose data outside the `properties` field of the STAC item, such as `assets` or `links`. To avoid this, the EOTDL can be used.
#
# Uncomment the following line to install eotdl if needed.

# %%
# !pip install eotdl

# %%
from pystac import Catalog
from eotdl.tools import stac_items_to_gdf

catalog = Catalog.from_file('example_data/jaca_dataset_stac/catalog.json')
collection = catalog.get_child('sentinel-2-l2a')

items = collection.get_all_items()
gdf = stac_items_to_gdf(items)

gdf.head()
# Out:
#                                             geometry  proj:epsg proj:shape  \
# 0  POLYGON ((-0.55703 42.56941, -0.55703 42.57571...       4326   [72, 75]
# 1  POLYGON ((-0.55703 42.56941, -0.55703 42.57571...       4326   [72, 75]
# 2  POLYGON ((-0.55703 42.56941, -0.55703 42.57571...       4326   [72, 75]
# 3  POLYGON ((-0.55703 42.56941, -0.55703 42.57571...       4326   [72, 75]
#
#                                       proj:transform constellation  \
# 0  [0.00012437333333333337, 0.0, -0.557034, 0.0, ...    Sentinel-2
# 1  [0.00012437333333333337, 0.0, -0.557034, 0.0, ...    Sentinel-2
# 2  [0.00012437333333333337, 0.0, -0.557034, 0.0, ...    Sentinel-2
# 3  [0.00012437333333333337, 0.0, -0.557034, 0.0, ...    Sentinel-2
#
#      platform   instruments  gsd  \
# 0  Sentinel-2  [Sentinel-2]   10
# 1  Sentinel-2  [Sentinel-2]   10
# 2  Sentinel-2  [Sentinel-2]   10
# 3  Sentinel-2  [Sentinel-2]   10
#
#                                             eo:bands              datetime  \
# 0  [{'name': 'B02', 'common_name': 'blue', 'descr...  2020-01-09T00:00:00Z
# 1  [{'name': 'B02', 'common_name': 'blue', 'descr...  2020-01-01T00:00:00Z
# 2  [{'name': 'B02', 'common_name': 'blue', 'descr...  2020-01-06T00:00:00Z
# 3  [{'name': 'B02', 'common_name': 'blue', 'descr...  2020-01-04T00:00:00Z
#
#        id     type                                    stac_extensions
# 0  Jaca_1  Feature  [https://stac-extensions.github.io/projection/...
# 1  Jaca_2  Feature  [https://stac-extensions.github.io/projection/...
# 2  Jaca_3  Feature  [https://stac-extensions.github.io/projection/...
# 3  Jaca_4  Feature  [https://stac-extensions.github.io/projection/...
